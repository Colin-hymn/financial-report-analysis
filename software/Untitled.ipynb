# %%
import akshare as ak
stock_zcfz_em_df = ak.stock_zcfz_em(date="20240331")
print(stock_zcfz_em_df)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
#         序号    股票代码   股票简称       资产-货币资金       资产-应收账款         资产-存货  \
# 0        1  603156   养元饮品  2.694087e+09  8.504620e+07  4.954271e+08
# 1        2  002569   ST步森  2.046171e+07  5.929689e+07  3.510340e+07
# 2        3  603260   合盛硅业  1.994771e+09  1.108960e+09  9.386126e+09
# 3        4  300417   南华仪器  9.511391e+07  2.660779e+07  8.352440e+07
# 4        5  300081   恒信东方  8.468683e+07  1.726053e+08  4.263620e+08
# ...    ...     ...    ...           ...           ...           ...
# 5123  5124  300076  GQY视讯  6.360493e+07  1.065645e+08  4.957959e+07
# 5124  5125  002644   佛慈制药  3.653386e+08  3.597726e+08  3.798694e+08
# 5125  5126  603058   永吉股份  1.206585e+08  3.419397e+08  1.824012e+08
# 5126  5127  600873   梅花生物  4.618039e+09  7.660051e+08  3.170362e+09
# 5127  5128  000818   航锦科技  4.479939e+08  1.047185e+09  8.103612e+08
#
#             资产-总资产   资产-总资产同比       负债-应付账款     负债-预收账款        负债-总负债  \
# ...

# %%
sh_603986 = stock_zcfz_em_df.loc[stock_zcfz_em_df['股票代码']=='603986']

# %%
print(603986
     )
# Out:
# 603986

# %%
print(sh_603986)
# Out:
#         序号    股票代码  股票简称       资产-货币资金       资产-应收账款         资产-存货  \
# 4821  4822  603986  兆易创新  8.048171e+09  1.881040e+08  1.977523e+09
#
#             资产-总资产  资产-总资产同比       负债-应付账款  负债-预收账款        负债-总负债   负债-总负债同比  \
# 4821  1.706618e+10  2.716238  6.221479e+08      NaN  1.728288e+09  37.954872
#
#           资产负债率        股东权益合计        公告日期
# 4821  10.126976  1.533789e+10  2024-04-20

# %%
import time
t = time.localtime()
type(t.tm_year )
# Out:
# int

# %%
thisyear = t.tm_year
disclose_date = ['0331','0630','0930','1231']
year = [str(x) for x in range(thisyear-8,thisyear+1)]
result = [x + y for x in year for y in disclose_date]
our_range = result[-3:-len(result)-1:-1]
our_range
# Out:
# ['20240630',
#  '20240331',
#  '20231231',
#  '20230930',
#  '20230630',
#  '20230331',
#  '20221231',
#  '20220930',
#  '20220630',
#  '20220331',
#  '20211231',
#  '20210930',
#  '20210630',
#  '20210331',
#  '20201231',
#  '20200930',
#  '20200630',
#  '20200331',
#  '20191231',
#  '20190930',
#  '20190630',
#  '20190331',
#  '20181231',
#  '20180930',
#  '20180630',
#  '20180331',
#  '20171231',
#  '20170930',
#  '20170630',
#  '20170331',
#  '20161231',
#  '20160930',
#  '20160630',
#  '20160331']

# %%
dict = {}
for i in our_range:
    stock_zcfz_em_df = ak.stock_zcfz_em(date=i)
    dict[i] = stock_zcfz_em_df
# Out:
# ...
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:652, in HTTPSConnection.connect(self)
# ...

# %%
print(dict
     )
# Out:
# {'20240630':         序号    股票代码  股票简称       资产-货币资金       资产-应收账款         资产-存货  \
# 0        1  001238  浙江正特  3.708809e+08  2.587085e+08  3.462138e+08
# 1        2  688737  中自科技  4.946144e+07  4.170682e+08  3.510898e+08
# 2        3  301556  托普云农  2.175687e+08  9.105622e+07  4.806388e+07
# 3        4  301522  上大股份  2.660313e+08  5.015855e+08  8.452013e+08
# 4        5  688184  帕瓦股份  2.976475e+08  2.669328e+08  7.802433e+08
# ...    ...     ...   ...           ...           ...           ...
# 5102  5103  300721  怡达股份  1.165078e+08  1.422178e+08  2.700093e+08
# 5103  5104  603668  天马科技  3.979412e+08  6.816258e+08  2.827110e+09
# 5104  5105  002245  蔚蓝锂芯  4.549495e+08  1.428709e+09  1.508247e+09
# 5105  5106  002648  卫星化学  4.473915e+09  9.251542e+08  5.160354e+09
# 5106  5107  300962  中金辐照  3.297540e+08  4.024619e+07  1.710750e+06
#
#             资产-总资产  资产-总资产同比       负债-应付账款      负债-预收账款        负债-总负债  \
# 0     1.626811e+09  0.834338  1.575200e+08          NaN  5.006707e+08
# ...

# %%
print(dict['20160331'])
# Out:
#         序号    股票代码  股票简称       资产-货币资金       资产-应收账款         资产-存货  \
# 0        1  300094  国联水产  1.379704e+08  6.104328e+08  1.080254e+09
# 1        2  688168   安博通  4.647818e+07  1.450874e+07  3.316411e+06
# 2        3  000713  丰乐种业  2.290056e+08  9.354656e+07  5.585920e+08
# 3        4  002181   粤传媒  5.347068e+08  3.752065e+08  1.074822e+08
# 4        5  603938  三孚股份  6.317496e+07  4.219756e+07  6.660368e+07
# ...    ...     ...   ...           ...           ...           ...
# 2866  2867  000600  建投能源  1.424829e+09  1.036239e+09  1.926996e+08
# 2867  2868  600312  平高电气  3.913065e+08  5.617045e+09  1.640334e+09
# 2868  2869  300420  五洋自控  1.793912e+08  2.847909e+08  1.993969e+08
# 2869  2870  300336   新文退  2.523646e+08  1.165636e+09  5.521371e+08
# 2870  2871  002707  众信旅游  5.447236e+08  3.608880e+08  5.397896e+05
#
#             资产-总资产    资产-总资产同比       负债-应付账款       负债-预收账款        负债-总负债  \
# 0     2.597491e+09    0.911996  1.952099e+08  3.495964e+07  8.668551e+08
# ...

# %%
stock_financial_report_sina_df = ak.stock_financial_report_sina(stock="sh600600", symbol="资产负债表")
print(stock_financial_report_sina_df)
# Out:
#          报告日 流动资产           货币资金 结算备付金 拆出资金       交易性金融资产 买入返售金融资产 衍生金融资产  \
# 0   20240630  NaN  24466683530.0   NaN  NaN  2812664867.0      NaN    NaN
# 1   20240331  NaN  21601487582.0   NaN  NaN  3041064846.0      NaN    NaN
# 2   20231231  NaN  19282104642.0   NaN  NaN  1924078158.0      NaN    NaN
# 3   20230930  NaN  17332174826.0   NaN  NaN  4897715110.0      NaN    NaN
# 4   20230630  NaN  18677844577.0   NaN  NaN  7086564553.0      NaN    NaN
# ..       ...  ...            ...   ...  ...           ...      ...    ...
# 95  19990630  NaN    664791660.0   NaN  NaN           NaN      NaN    NaN
# 96  19981231  NaN    617779169.0   NaN  NaN           NaN      NaN    NaN
# 97  19980630  NaN    868077687.0   NaN  NaN       94280.0      NaN    NaN
# 98  19971231  NaN    737698524.0   NaN  NaN       94280.0      NaN    NaN
# 99  19970630  NaN            NaN   NaN  NaN           NaN      NaN    NaN
#
#       应收票据及应收账款        应收票据  ...   归属于母公司股东权益合计       少数股东权益 所有者权益(或股东权益)合计  \
# ...

# %%
stock_financial_report_sina_df.columns
# Out:
# Index(['报告日', '流动资产', '货币资金', '结算备付金', '拆出资金', '交易性金融资产', '买入返售金融资产', '衍生金融资产',
#        '应收票据及应收账款', '应收票据',
#        ...
#        '归属于母公司股东权益合计', '少数股东权益', '所有者权益(或股东权益)合计', '负债和所有者权益(或股东权益)总计', '数据源',
#        '是否审计', '公告日期', '币种', '类型', '更新日期'],
#       dtype='object', length=147)

# %%
profit_table = ak.stock_financial_report_sina(stock="sh600600", symbol="利润表")
print(profit_table)
profit_table.to_csv('603986利润表.csv')
# Out:
#          报告日          营业总收入           营业收入 利息收入 已赚保费 手续费及佣金收入 房地产销售收入 其他业务收入  \
# 0   20240630  20068307930.0  20068307930.0  NaN  NaN      NaN     NaN    NaN
# 1   20240331  10150014997.0  10150014997.0  NaN  NaN      NaN     NaN    NaN
# 2   20231231  33936522741.0  33936522741.0  NaN  NaN      NaN     NaN    NaN
# 3   20230930  30978047855.0  30978047855.0  NaN  NaN      NaN     NaN    NaN
# 4   20230630  21591789633.0  21591789633.0  NaN  NaN      NaN     NaN    NaN
# ..       ...            ...            ...  ...  ...      ...     ...    ...
# 95  19990630   1228665008.0   1229953255.0  NaN  NaN      NaN     NaN    NaN
# 96  19981231   1727366931.0   1722713205.0  NaN  NaN      NaN     NaN    NaN
# 97  19980630    850744555.0    849619745.0  NaN  NaN      NaN     NaN    NaN
# 98  19971231   1527877796.0   1531433178.0  NaN  NaN      NaN     NaN    NaN
# 99  19970630    850431162.0    853798321.0  NaN  NaN      NaN     NaN    NaN
#
# ...
